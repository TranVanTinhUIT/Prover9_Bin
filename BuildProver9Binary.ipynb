# %%
# !git clone https://github.com/ai4reason/Prover9.git
# Out:
# Cloning into 'Prover9'...
# remote: Enumerating objects: 685, done.
# remote: Counting objects: 100% (9/9), done.
# remote: Compressing objects: 100% (7/7), done.
# remote: Total 685 (delta 2), reused 9 (delta 2), pack-reused 676 (from 1)
# Receiving objects: 100% (685/685), 1.85 MiB | 4.10 MiB/s, done.
# Resolving deltas: 100% (136/136), done.

# %%
# %cd ./Prover9
# Out:
# /content/Prover9

# %%
# !sudo apt update
# !sudo apt install build-essential
# Out:
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Get:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Hit:3 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:4 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:5 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:6 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Get:7 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [1,383 kB]
# Get:8 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# Get:9 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease [18.1 kB]
# Hit:10 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Get:11 https://r2u.stat.illinois.edu/ubuntu jammy/main all Packages [8,824 kB]
# Hit:12 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# ...

# %%
# %cd /content/Prover9/ladr
# !make

# %%
# %cd /content/Prover9
# !make all
# Out:
# /content/Prover9
# cd ladr         && make lib
# make[1]: Entering directory '/content/Prover9/ladr'
# make libladr.a
# make[2]: Entering directory '/content/Prover9/ladr'
# gcc  -O -Wall   -c -o order.o order.c
# gcc  -O -Wall   -c -o clock.o clock.c
# gcc  -O -Wall   -c -o nonport.o nonport.c
# gcc  -O -Wall   -c -o fatal.o fatal.c
# gcc  -O -Wall   -c -o ibuffer.o ibuffer.c
# gcc  -O -Wall   -c -o memory.o memory.c
# gcc  -O -Wall   -c -o hash.o hash.c
# gcc  -O -Wall   -c -o string.o string.c
# gcc  -O -Wall   -c -o strbuf.o strbuf.c
# gcc  -O -Wall   -c -o glist.o glist.c
# gcc  -O -Wall   -c -o options.o options.c
# gcc  -O -Wall   -c -o symbols.o symbols.c
# gcc  -O -Wall   -c -o avltree.o avltree.c
# avltree.c: In function ‘p_avl’:
# avltree.c:658:21: warning: cast from pointer to integer of different size [-Wpointer-to-int-cast]
#   658 |     printf("%4d\n", (int) p->item);
#       |                     ^
# gcc  -O -Wall   -c -o term.o term.c
# ...

# %%
# !make test1
# Out:
# bin/prover9 -f prover9.examples/x2.in | bin/prooftrans parents_only
# ============================== prooftrans ============================
# Prover9 (64) version 2017-11A (CIIRC), November 2017.
# Process 1749 was started by root on d795b7913076,
# Thu Apr 10 08:02:28 2025
# The command was "bin/prover9 -f prover9.examples/x2.in".
# ============================== end of head ===========================
#
# ============================== end of input ==========================
# -------- Proof 1 --------
#
# THEOREM PROVED
#
# ------ process 1749 exit (max_proofs) ------
#
# ============================== PROOF =================================
#
# % -------- Comments from original proof --------
# % Proof 1 at 0.00 (+ 0.00) seconds.
# % Length of proof is 16.
# % Level of proof is 7.
# % Maximum clause weight is 11.000.
# % Given clauses 12 (1.714 givens/level).
#
#
# 1 x * y = y * x # label(non_clause) # label(goal).  [].
# 2 e * x = x.  [].
# 3 x' * x = e.  [].
# ...

# %%
# %cd /content
# !zip -r prover9_bin.zip /content/Prover9/bin
# Out:
# /content
#   adding: content/Prover9/bin/ (stored 0%)
#   adding: content/Prover9/bin/fof-prover9 (deflated 58%)
#   adding: content/Prover9/bin/autosketches4 (deflated 58%)
#   adding: content/Prover9/bin/gen_trc_defs (deflated 59%)
#   adding: content/Prover9/bin/directproof (deflated 58%)
#   adding: content/Prover9/bin/miniscope (deflated 58%)
#   adding: content/Prover9/bin/test_complex (deflated 59%)
#   adding: content/Prover9/bin/perm3 (deflated 58%)
#   adding: content/Prover9/bin/isofilter2 (deflated 58%)
#   adding: content/Prover9/bin/get_interps (deflated 22%)
#   adding: content/Prover9/bin/unfast (deflated 58%)
#   adding: content/Prover9/bin/mirror-flip (deflated 58%)
#   adding: content/Prover9/bin/interpfilter (deflated 58%)
#   adding: content/Prover9/bin/interpformat (deflated 58%)
#   adding: content/Prover9/bin/prochints (deflated 58%)
#   adding: content/Prover9/bin/upper-covers (deflated 58%)
#   adding: content/Prover9/bin/attack (deflated 64%)
# ...

# %%
from google.colab import files
files.download("prover9_bin.zip")
